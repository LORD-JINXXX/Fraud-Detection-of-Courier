# %% [markdown]
# #Importing Libraries

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import pandas_datareader as DataReader
from datetime import date

# %%
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #Loading the Data

# %%
df_pincode_zones = pd.read_excel("Company X - Pincode Zones.xlsx")
df_pincode_zones
# Out:
#      Warehouse Pincode  Customer Pincode Zone
# 0               121003            507101    d
# 1               121003            486886    d
# 2               121003            532484    d
# 3               121003            143001    b
# 4               121003            515591    d
# ..                 ...               ...  ...
# 119             121003            325207    b
# 120             121003            303702    b
# 121             121003            313301    b
# 122             121003            173212    e
# 123             121003            302020    b
#
# [124 rows x 3 columns]

# %%
df_pincode_zones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Warehouse Pincode  124 non-null    int64
#  1   Customer Pincode   124 non-null    int64
#  2   Zone               124 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 3.0+ KB

# %%
df_pincode_zones = df_pincode_zones.rename(columns = {"Zone":"Delivery Zone As Per X"})
df_pincode_zones
# Out:
#      Warehouse Pincode  Customer Pincode Delivery Zone As Per X
# 0               121003            507101                      d
# 1               121003            486886                      d
# 2               121003            532484                      d
# 3               121003            143001                      b
# 4               121003            515591                      d
# ..                 ...               ...                    ...
# 119             121003            325207                      b
# 120             121003            303702                      b
# 121             121003            313301                      b
# 122             121003            173212                      e
# 123             121003            302020                      b
#
# [124 rows x 3 columns]

# %%
df_courier_invoice = pd.read_excel("Courier Company - Invoice.xlsx")
df_courier_invoice
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# ...

# %%
df_courier_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AWB Code              124 non-null    int64
#  1   Order ID              124 non-null    int64
#  2   Charged Weight        124 non-null    float64
#  3   Warehouse Pincode     124 non-null    int64
#  4   Customer Pincode      124 non-null    int64
#  5   Zone                  124 non-null    object
#  6   Type of Shipment      124 non-null    object
#  7   Billing Amount (Rs.)  124 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.9+ KB

# %%
df_courier_invoice.rename(columns = {"Zone":"Delivery Zone Charged By Courier Company","Charged Weight":"Total Weight As Per Courier Company (KG)"},inplace=True)

# %%
df_courier_invoice
# Out:
#           AWB Code    Order ID  Total Weight As Per Courier Company (KG)  \
# 0    1091117222124  2001806232                                      1.30
# 1    1091117222194  2001806273                                      1.00
# 2    1091117222931  2001806408                                      2.50
# 3    1091117223244  2001806458                                      1.00
# 4    1091117229345  2001807012                                      0.15
# ..             ...         ...                                       ...
# 119  1091118551656  2001812941                                      0.73
# 120  1091117614452  2001809383                                      0.50
# 121  1091120922803  2001820978                                      0.50
# 122  1091121844806  2001811475                                      0.50
# 123  1091121846136  2001811305                                      0.50
#
#      Warehouse Pincode  Customer Pincode  \
# 0               121003            507101
# ...

# %%
df_SKU_master = pd.read_excel("Company X - SKU Master.xlsx")
df_SKU_master
# Out:
#               SKU  Weight (g)
# 0   8904223815682         210
# 1   8904223815859         165
# 2   8904223815866         113
# 3   8904223815873          65
# 4   8904223816214         120
# ..            ...         ...
# 61  8904223819505         210
# 62  8904223819499         210
# 63  8904223819512         210
# 64  8904223819543         300
# 65     SACHETS001          10
#
# [66 rows x 2 columns]

# %%
df_SKU_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SKU         66 non-null     object
#  1   Weight (g)  66 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.2+ KB

# %%
df_order_report = pd.read_excel("Company X - Order Report.xlsx")
df_order_report
# Out:
#      ExternOrderNo            SKU  Order Qty
# 0       2001827036  8904223818706        1.0
# 1       2001827036  8904223819093        1.0
# 2       2001827036  8904223819109        1.0
# 3       2001827036  8904223818430        1.0
# 4       2001827036  8904223819277        1.0
# ..             ...            ...        ...
# 395     2001806229  8904223818942        1.0
# 396     2001806229  8904223818850        1.0
# 397     2001806226  8904223818850        2.0
# 398     2001806210  8904223816214        1.0
# 399     2001806210  8904223818874        1.0
#
# [400 rows x 3 columns]

# %%
df_order_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ExternOrderNo  400 non-null    int64
#  1   SKU            400 non-null    object
#  2   Order Qty      400 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.5+ KB

# %%
rename_order_id=df_order_report.rename(columns={"ExternOrderNo":"Order ID"},inplace=True)
df_order_report.head()
# Out:
#      Order ID            SKU  Order Qty
# 0  2001827036  8904223818706        1.0
# 1  2001827036  8904223819093        1.0
# 2  2001827036  8904223819109        1.0
# 3  2001827036  8904223818430        1.0
# 4  2001827036  8904223819277        1.0

# %%
df_courier_rates = pd.read_excel("Courier Company - Rates.xlsx")
df_courier_rates
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %%
df_courier_rates.info()
df_courier_rates.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fwd_a_fixed       1 non-null      float64
#  1   fwd_a_additional  1 non-null      float64
#  2   fwd_b_fixed       1 non-null      int64
#  3   fwd_b_additional  1 non-null      float64
#  4   fwd_c_fixed       1 non-null      float64
#  5   fwd_c_additional  1 non-null      float64
#  6   fwd_d_fixed       1 non-null      float64
#  7   fwd_d_additional  1 non-null      float64
#  8   fwd_e_fixed       1 non-null      float64
#  9   fwd_e_additional  1 non-null      float64
#  10  rto_a_fixed       1 non-null      float64
#  11  rto_a_additional  1 non-null      float64
#  12  rto_b_fixed       1 non-null      float64
#  13  rto_b_additional  1 non-null      float64
#  14  rto_c_fixed       1 non-null      float64
#  15  rto_c_additional  1 non-null      float64
# ...

# %% [markdown]
# #EDA

# %%
df_sku_order_report=pd.merge(df_order_report,df_SKU_master,how="left",on="SKU")

# %%
df_sku_order_report.info()
df_sku_order_report.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401 entries, 0 to 400
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order ID    401 non-null    int64
#  1   SKU         401 non-null    object
#  2   Order Qty   401 non-null    float64
#  3   Weight (g)  401 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 15.7+ KB
#      Order ID            SKU  Order Qty  Weight (g)
# 0  2001827036  8904223818706        1.0         127
# 1  2001827036  8904223819093        1.0         150
# 2  2001827036  8904223819109        1.0         100
# 3  2001827036  8904223818430        1.0         165
# 4  2001827036  8904223819277        1.0         350

# %%
df_courier_X_pincode = df_pincode_zones.drop_duplicates(subset=['Customer Pincode'])
df_mg_courier_invoice = df_courier_invoice[['Order ID', 'Customer Pincode','Type of Shipment']]
df_courier_pincode=df_mg_courier_invoice.merge(df_courier_X_pincode,on='Customer Pincode')
df_courier_pincode.sample()
# Out:
#        Order ID  Customer Pincode Type of Shipment  Warehouse Pincode  \
# 101  2001807785            306116  Forward charges             121003
#
#     Delivery Zone As Per X
# 101                      b

# %%
df_sku_inorder_report = df_sku_order_report.merge(df_courier_pincode,on = 'Order ID')
df_sku_inorder_report.sample()
# Out:
#        Order ID            SKU  Order Qty  Weight (g)  Customer Pincode  \
# 398  2001806226  8904223818850        2.0         240            723146
#
#     Type of Shipment  Warehouse Pincode Delivery Zone As Per X
# 398  Forward charges             121003                      d

# %%
kg=1000

# %%
df_re_sku_inorder_report=df_sku_inorder_report.rename(columns={"Order Qty":"Order_Qty","Weight (g)":"Weight_g"})

# %%
convert_g_to_kg="""
Total_Weight_Per_Shipment=(Order_Qty*Weight_g)/@kg
 """
df_re_sku_inorder_report.eval(convert_g_to_kg,inplace=True,engine='python')

# %%
df_re_sku_inorder_report['Weight_g'].value_counts()
# Out:
# 240    98
# 127    59
# 133    41
# 112    40
# 120    22
# 350    19
# 210    15
# 165    15
# 121    12
# 100    11
# 115     8
# 290     8
# 65      7
# 113     5
# 137     5
# 500     5
# 140     4
# 130     4
# 600     4
# 232     3
# 10      3
# 150     2
# 110     2
# 170     2
# 490     1
# 160     1
# 250     1
# 102     1
# 30      1
# 300     1
# 552     1
# Name: Weight_g, dtype: int64

# %%
df_re_sku_inorder_report['Type of Shipment'].value_counts()
# Out:
# Forward charges            351
# Forward and RTO charges     50
# Name: Type of Shipment, dtype: int64

# %%
df_re_sku_inorder_report
# Out:
#        Order ID            SKU  Order_Qty  Weight_g  Customer Pincode  \
# 0    2001827036  8904223818706        1.0       127            173213
# 1    2001827036  8904223819093        1.0       150            173213
# 2    2001827036  8904223819109        1.0       100            173213
# 3    2001827036  8904223818430        1.0       165            173213
# 4    2001827036  8904223819277        1.0       350            173213
# ..          ...            ...        ...       ...               ...
# 396  2001806229  8904223818942        1.0       133            421204
# 397  2001806229  8904223818850        1.0       240            421204
# 398  2001806226  8904223818850        2.0       240            723146
# 399  2001806210  8904223816214        1.0       120            140604
# 400  2001806210  8904223818874        1.0       100            140604
#
#     Type of Shipment  Warehouse Pincode Delivery Zone As Per X  \
# ...

# %%
#Renmaing Columns

re_df_sku_inorder_report = df_re_sku_inorder_report.rename(columns={"Order_Qty":"Order Qty","Total_Weight_Per_Shipment":"Total Weight AS Per X (KG)","Weight_g":"Weight (g)"})
re_df_sku_inorder_report.sample()
# Out:
#        Order ID            SKU  Order Qty  Weight (g)  Customer Pincode  \
# 139  2001810697  8904223818850        1.0         240            324008
#
#     Type of Shipment  Warehouse Pincode Delivery Zone As Per X  \
# 139  Forward charges             121003                      b
#
#      Total Weight AS Per X (KG)
# 139                        0.24

# %% [markdown]
# #Function For Assigning Weight Slab

# %%
def weight_slab(weight):
    i=round(weight%1,1)
    if i==0.0:
        return weight
    elif i>0.5:
        return int(weight)+1.0
    else:
        return int(weight)+0.5

# %% [markdown]
# #Generation Of Weight Slab Column

# %%
##Generation of Weight Slab
re_df_sku_inorder_report['Weight Slab As Per X (KG)']=re_df_sku_inorder_report['Total Weight AS Per X (KG)'].apply(weight_slab)
df_courier_invoice['Weight Slab Charged By Courier Company (KG)']=(df_courier_invoice['Total Weight As Per Courier Company (KG)']).apply(weight_slab)

# %%
re_df_sku_inorder_report
# Out:
#        Order ID            SKU  Order Qty  Weight (g)  Customer Pincode  \
# 0    2001827036  8904223818706        1.0         127            173213
# 1    2001827036  8904223819093        1.0         150            173213
# 2    2001827036  8904223819109        1.0         100            173213
# 3    2001827036  8904223818430        1.0         165            173213
# 4    2001827036  8904223819277        1.0         350            173213
# ..          ...            ...        ...         ...               ...
# 396  2001806229  8904223818942        1.0         133            421204
# 397  2001806229  8904223818850        1.0         240            421204
# 398  2001806226  8904223818850        2.0         240            723146
# 399  2001806210  8904223816214        1.0         120            140604
# 400  2001806210  8904223818874        1.0         100            140604
#
#     Type of Shipment  Warehouse Pincode Delivery Zone As Per X  \
# ...

# %%
df_courier_invoice
# Out:
#           AWB Code    Order ID  Total Weight As Per Courier Company (KG)  \
# 0    1091117222124  2001806232                                      1.30
# 1    1091117222194  2001806273                                      1.00
# 2    1091117222931  2001806408                                      2.50
# 3    1091117223244  2001806458                                      1.00
# 4    1091117229345  2001807012                                      0.15
# ..             ...         ...                                       ...
# 119  1091118551656  2001812941                                      0.73
# 120  1091117614452  2001809383                                      0.50
# 121  1091120922803  2001820978                                      0.50
# 122  1091121844806  2001811475                                      0.50
# 123  1091121846136  2001811305                                      0.50
#
#      Warehouse Pincode  Customer Pincode  \
# 0               121003            507101
# ...

# %% [markdown]
# #Computation Of Expected Charge

# %%
total_Expected_charge=[]
for i in range(len(re_df_sku_inorder_report)):
    fwd_category='fwd_'+re_df_sku_inorder_report['Delivery Zone As Per X'][i]
    fwd_fixed=df_courier_rates[fwd_category+'_fixed'][0]
    fwd_additional=df_courier_rates[fwd_category+'_additional'][0]
    rto_category='rto_'+re_df_sku_inorder_report['Delivery Zone As Per X'][i]
    rto_fixed=df_courier_rates[rto_category+'_fixed'][0]
    rto_additional=df_courier_rates[rto_category+'_additional'][0]
    if re_df_sku_inorder_report['Type of Shipment'][i]=='Forward charges':
        if re_df_sku_inorder_report['Weight Slab As Per X (KG)'][i]<=0.5:
            total_Expected_charge.append(fwd_fixed)
        else:
            additional_weight=(re_df_sku_inorder_report['Weight Slab As Per X (KG)'][i]-0.5)/0.5
            total_Expected_charge.append(fwd_fixed+additional_weight*fwd_additional)
    if re_df_sku_inorder_report['Type of Shipment'][i]=='Forward and RTO charges':
        if re_df_sku_inorder_report['Weight Slab As Per X (KG)'][i]<=0.5:
            total_Expected_charge.append(fwd_fixed+rto_fixed)
        else:
            additional_weight=(re_df_sku_inorder_report['Weight Slab As Per X (KG)'][i]-0.5)/0.5
            total_Expected_charge.append(fwd_fixed+additional_weight*(fwd_additional+rto_additional))

re_df_sku_inorder_report['Expected Charge As Per X (Rs.)']=total_Expected_charge

# %%
re_df_sku_inorder_report.columns
# Out:
# Index(['Order ID', 'SKU', 'Order Qty', 'Weight (g)', 'Customer Pincode',
#        'Type of Shipment', 'Warehouse Pincode', 'Delivery Zone As Per X',
#        'Total Weight AS Per X (KG)', 'Weight Slab As Per X (KG)',
#        'Expected Charge As Per X (Rs.)'],
#       dtype='object')

# %%
Output2=re_df_sku_inorder_report[['Order ID',
       'Type of Shipment', 'Delivery Zone As Per X',
       'Total Weight AS Per X (KG)', 'Weight Slab As Per X (KG)',
       'Expected Charge As Per X (Rs.)']]

# %%
df_courier_invoice.columns
# Out:
# Index(['AWB Code', 'Order ID', 'Total Weight As Per Courier Company (KG)',
#        'Warehouse Pincode', 'Customer Pincode',
#        'Delivery Zone Charged By Courier Company', 'Type of Shipment',
#        'Billing Amount (Rs.)', 'Weight Slab Charged By Courier Company (KG)'],
#       dtype='object')

# %%
Output1=df_courier_invoice[['AWB Code', 'Order ID','Total Weight As Per Courier Company (KG)',
        'Delivery Zone Charged By Courier Company','Billing Amount (Rs.)', 'Weight Slab Charged By Courier Company (KG)']]

# %%
df_merged_output=Output2.merge(Output1,on='Order ID',how='left')
df_merged_output.head(5)
# Out:
#      Order ID Type of Shipment Delivery Zone As Per X  \
# 0  2001827036  Forward charges                      e
# 1  2001827036  Forward charges                      e
# 2  2001827036  Forward charges                      e
# 3  2001827036  Forward charges                      e
# 4  2001827036  Forward charges                      e
#
#    Total Weight AS Per X (KG)  Weight Slab As Per X (KG)  \
# 0                       0.127                        0.5
# 1                       0.150                        0.5
# 2                       0.100                        0.5
# 3                       0.165                        0.5
# 4                       0.350                        0.5
#
#    Expected Charge As Per X (Rs.)       AWB Code  \
# 0                            56.6  1091122418320
# 1                            56.6  1091122418320
# 2                            56.6  1091122418320
# 3                            56.6  1091122418320
# ...

# %%
resultant_output1=df_merged_output.copy()

# %%
resultant_output1=resultant_output1.rename(columns={'AWB Code':'AWB Number','Billing Amount (Rs.)':'Charges_Billed_By_Courier_Company_Rs','Expected Charge As Per X (Rs.)':'Expected_Charge_As_Per_X_Rs'})
resultant_output1.head()
# Out:
#      Order ID Type of Shipment Delivery Zone As Per X  \
# 0  2001827036  Forward charges                      e
# 1  2001827036  Forward charges                      e
# 2  2001827036  Forward charges                      e
# 3  2001827036  Forward charges                      e
# 4  2001827036  Forward charges                      e
#
#    Total Weight AS Per X (KG)  Weight Slab As Per X (KG)  \
# 0                       0.127                        0.5
# 1                       0.150                        0.5
# 2                       0.100                        0.5
# 3                       0.165                        0.5
# 4                       0.350                        0.5
#
#    Expected_Charge_As_Per_X_Rs     AWB Number  \
# 0                         56.6  1091122418320
# 1                         56.6  1091122418320
# 2                         56.6  1091122418320
# 3                         56.6  1091122418320
# 4                         56.6  1091122418320
#
# ...

# %% [markdown]
# #Computation Of Difference Between Expected Charges And Billed Charges

# %%
diff_bw_ec_bc="""
Difference_Between_Expected_Charges_and_Billed_Charges_Rs =(Expected_Charge_As_Per_X_Rs - Charges_Billed_By_Courier_Company_Rs)
"""
resultant_output1.eval(diff_bw_ec_bc,inplace=True,engine='python')

# %%
resultant_output1=resultant_output1.rename(columns={'Charges_Billed_By_Courier_Company_Rs':'Charges Billed By Courier Company (Rs.)','Expected_Charge_As_Per_X_Rs':'Expected Charge As Per X (Rs.)','Difference_Between_Expected_Charges_and_Billed_Charges_Rs':'Difference Between Expected Charges And Billed Charges (Rs.)'})

# %%
writer = pd.ExcelWriter('Expected_Result.xlsx',if_sheet_exists="replace",engine='openpyxl',mode="a")

# %%
resultant_output1.to_excel(writer,sheet_name='Calculations')
calculations=writer.save()

# %% [markdown]
# #Computation Of Total Orders

# %%
correctly_charged=resultant_output1[resultant_output1['Difference Between Expected Charges And Billed Charges (Rs.)']==0.0]
correctly=["Total Orders where X has been correctly charged",len(correctly_charged),sum(correctly_charged['Charges Billed By Courier Company (Rs.)'])]

over_charged=resultant_output1[resultant_output1['Difference Between Expected Charges And Billed Charges (Rs.)']<0.0]
over=["Total Orders where X has been over charged",len(over_charged),np.absolute(sum(over_charged['Difference Between Expected Charges And Billed Charges (Rs.)']))]

under_charged=resultant_output1[resultant_output1['Difference Between Expected Charges And Billed Charges (Rs.)']>0.0]
under=["Total Orders where X has been under charged",len(under_charged),np.absolute(sum(under_charged['Difference Between Expected Charges And Billed Charges (Rs.)']))]

# %%
resultant_output2=pd.DataFrame([correctly,over,under],columns=['Description','Count','Amount (Rs.)'])

# %%
resultant_output2
# Out:
#                                        Description  Count  Amount (Rs.)
# 0  Total Orders where X has been correctly charged     12         507.6
# 1       Total Orders where X has been over charged    380       31737.5
# 2      Total Orders where X has been under charged      9         165.2

# %% [markdown]
# #Generation Of Resultant Summary Output File

# %%
resultant_output2.to_excel(writer,sheet_name='Summary')
writer.save()

# %%
df_sheet_multi = pd.read_excel('Expected_Result.xlsx', sheet_name=['Calculations', 'Summary'])
df_sheet_multi['Calculations']
# Out:
#      Unnamed: 0    Order ID Type of Shipment Delivery Zone As Per X  \
# 0             0  2001827036  Forward charges                      e
# 1             1  2001827036  Forward charges                      e
# 2             2  2001827036  Forward charges                      e
# 3             3  2001827036  Forward charges                      e
# 4             4  2001827036  Forward charges                      e
# ..          ...         ...              ...                    ...
# 396         396  2001806229  Forward charges                      d
# 397         397  2001806229  Forward charges                      d
# 398         398  2001806226  Forward charges                      d
# 399         399  2001806210  Forward charges                      b
# 400         400  2001806210  Forward charges                      b
#
#      Total Weight AS Per X (KG)  Weight Slab As Per X (KG)  \
# 0                         0.127                        0.5
# ...

# %%
df_sheet_multi['Summary']
# Out:
#    Unnamed: 0                                      Description  Count  \
# 0           0  Total Orders where X has been correctly charged     12
# 1           1       Total Orders where X has been over charged    380
# 2           2      Total Orders where X has been under charged      9
#
#    Amount (Rs.)
# 0         507.6
# 1       31737.5
# 2         165.2
